# %% [markdown]
# # List of Universities in karnataka

# %% [markdown]
# #### importing pandas and numpy

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### reading the csv file using pandas

# %%
karnataka_universities = pd.read_csv('List_University_Karnataka.csv')
karnataka_universities
# Out:
#     slno                                 Name_of_University Type_of_University
# 0      1                    Bangalore University, Bangalore                 PA
# 1      2                          Bengaluru City University                 PA
# 2      3                         Bengaluru North University                 PA
# 3      4                    Davangere University, Davangere                 PA
# 4      5                      Gulbarga University, Gulbarga                 PA
# 5      6                      Karnataka Sanskrit University                 PA
# 6      7          Karnataka State Women University, Bijapur                 PA
# 7      8                      Karnataka University, Dharwad                 PA
# 8      9        Kuvempu University, Shankaraghatta, Shimoga                 PA
# 9     10                    Mangalore University, Mangalore                 PA
# 10    11                Rani Channamma University, Belagavi                 PA
# 11    12                          Tumkur University, Tumkur                 PA
# 12    13                      University of Mysore , Mysore                 PA
# 13    14    Vesveswaraiah Technological University, Belgaum                 PA
# 14    15  Vijayanagara Sri Krishnadevaraya University, B...                 PA
# 15    16        University of Agricultural Science, Raichur                 PA
# 16    17            Karnataka State Open University, Mysore                 PN
# 17    18              Kannada University, Hampi, Kamalapura                 PN
# 18    19       Karnataka Janapada Vishwavidyalaya, Gotagodi                 PN
# 19    20  Karnataka State Dr. Gangubai Hangal Music And ...                 PN
# 20    21                        Maharani Cluster University                 PN
# 21    22                                  Mandya University                 PN
# 22    23                             Nrupathunga University                 PN
# 23    24  Dr .B. R. Ambedkar School of Economics University                 PN
# 24    26                        Adichunchanagiri University                 HP
# 25    27                     Alliance University. Bangalore                 HP
# 26    28                  Azim Premji University, Bangalore                 HP
# 27    29                          CMR University, Bangalore                 HP
# 28    30                         Dayananda Sagar University                 HP
# 29    31                  Garden City University, Bangalore                 HP
# 30    32      JSS Science And Technology University, Mysore                 HP
# 31    33                     K.L.E Technological University                 HP
# 32    34              Khaja Bandanawaz University, Gulbarga                 HP
# 33    35  M.S. Ramaiah University Of Applied Sciences, B...                 HP
# 34    36                           PES University, Banglore                 HP
# 35    37                  Presidency University , Bengaluru                 HP
# 36    38                         Reva University, Bangalore                 HP
# 37    39               Sharanabasava University, Kalaburagi                 HP
# 38    40      Shri Dharmasthala Manjunatheshwara University                 HP
# 39    41                     Srinivas University, Mangalore                 HP
# 40    42  The University Of Trans-Disciplinary Health Sc...                 HP
# 41    44                       B.L.D.E. University, Bijapur                  D
# 42    45                       Christ University, Bangalore                  D
# 43    46  International Institute Of Information Technol...                  D
# 44    47             Indian Institute Of Science, Bangalore                  D
# 45    48                          Jain University,Bangalore                  D
# 46    49  Jawaharlal Nehru Centre For Advanced Scientifi...                  D
# 47    50         Jss Academy Of Higher Education & Research                  D
# 48    51  K.L.E. Academy Of Higher Education And Researc...                  D
# 49    52       Manipal Academy Of Higher Education, Manipal                  D
# 50    53                        Nitte University, Mangalore                  D
# 51    54  Sri Devraj Urs Acaedmy Of Highehr Education An...                  D
# 52    55  Sri Siddharatha Academy Of Higher Education, T...                  D
# 53    56  Swami Vivekananda Yoga Anusandhana Samsthan, B...                  D
# 54    57  Yenepoya ( deemed to be University), Deralakat...                  D

# %% [markdown]
# #### getting first 5 and last 5 rows using head() and tail()

# %%
karnataka_universities.head()
# Out:
#    slno               Name_of_University Type_of_University
# 0     1  Bangalore University, Bangalore                 PA
# 1     2        Bengaluru City University                 PA
# 2     3       Bengaluru North University                 PA
# 3     4  Davangere University, Davangere                 PA
# 4     5    Gulbarga University, Gulbarga                 PA

# %%
karnataka_universities.tail()
# Out:
#     slno                                 Name_of_University Type_of_University
# 50    53                        Nitte University, Mangalore                  D
# 51    54  Sri Devraj Urs Acaedmy Of Highehr Education An...                  D
# 52    55  Sri Siddharatha Academy Of Higher Education, T...                  D
# 53    56  Swami Vivekananda Yoga Anusandhana Samsthan, B...                  D
# 54    57  Yenepoya ( deemed to be University), Deralakat...                  D

# %%
type(karnataka_universities)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #### removing slno column

# %%
karnataka_universities = karnataka_universities.drop('slno', axis=1)
karnataka_universities
# Out:
#                                    Name_of_University Type_of_University
# 0                     Bangalore University, Bangalore                 PA
# 1                           Bengaluru City University                 PA
# 2                          Bengaluru North University                 PA
# 3                     Davangere University, Davangere                 PA
# 4                       Gulbarga University, Gulbarga                 PA
# 5                       Karnataka Sanskrit University                 PA
# 6           Karnataka State Women University, Bijapur                 PA
# 7                       Karnataka University, Dharwad                 PA
# 8         Kuvempu University, Shankaraghatta, Shimoga                 PA
# 9                     Mangalore University, Mangalore                 PA
# 10                Rani Channamma University, Belagavi                 PA
# 11                          Tumkur University, Tumkur                 PA
# 12                      University of Mysore , Mysore                 PA
# 13    Vesveswaraiah Technological University, Belgaum                 PA
# 14  Vijayanagara Sri Krishnadevaraya University, B...                 PA
# 15        University of Agricultural Science, Raichur                 PA
# 16            Karnataka State Open University, Mysore                 PN
# 17              Kannada University, Hampi, Kamalapura                 PN
# 18       Karnataka Janapada Vishwavidyalaya, Gotagodi                 PN
# 19  Karnataka State Dr. Gangubai Hangal Music And ...                 PN
# 20                        Maharani Cluster University                 PN
# 21                                  Mandya University                 PN
# 22                             Nrupathunga University                 PN
# 23  Dr .B. R. Ambedkar School of Economics University                 PN
# 24                        Adichunchanagiri University                 HP
# 25                     Alliance University. Bangalore                 HP
# 26                  Azim Premji University, Bangalore                 HP
# 27                          CMR University, Bangalore                 HP
# 28                         Dayananda Sagar University                 HP
# 29                  Garden City University, Bangalore                 HP
# 30      JSS Science And Technology University, Mysore                 HP
# 31                     K.L.E Technological University                 HP
# 32              Khaja Bandanawaz University, Gulbarga                 HP
# 33  M.S. Ramaiah University Of Applied Sciences, B...                 HP
# 34                           PES University, Banglore                 HP
# 35                  Presidency University , Bengaluru                 HP
# 36                         Reva University, Bangalore                 HP
# 37               Sharanabasava University, Kalaburagi                 HP
# 38      Shri Dharmasthala Manjunatheshwara University                 HP
# 39                     Srinivas University, Mangalore                 HP
# 40  The University Of Trans-Disciplinary Health Sc...                 HP
# 41                       B.L.D.E. University, Bijapur                  D
# 42                       Christ University, Bangalore                  D
# 43  International Institute Of Information Technol...                  D
# 44             Indian Institute Of Science, Bangalore                  D
# 45                          Jain University,Bangalore                  D
# 46  Jawaharlal Nehru Centre For Advanced Scientifi...                  D
# 47         Jss Academy Of Higher Education & Research                  D
# 48  K.L.E. Academy Of Higher Education And Researc...                  D
# 49       Manipal Academy Of Higher Education, Manipal                  D
# 50                        Nitte University, Mangalore                  D
# 51  Sri Devraj Urs Acaedmy Of Highehr Education An...                  D
# 52  Sri Siddharatha Academy Of Higher Education, T...                  D
# 53  Swami Vivekananda Yoga Anusandhana Samsthan, B...                  D
# 54  Yenepoya ( deemed to be University), Deralakat...                  D

# %% [markdown]
# #### total number of universities in karnataka

# %%
total_universities = karnataka_universities.count()
total_universities
# Out:
# Name_of_University    55
# Type_of_University    55
# dtype: int64

# %%
karnataka_universities['Type_of_University'].value_counts()
# Out:
# Type_of_University
# Private University                      17
# Public (State) University               16
# Deemed University                       14
# Public (Specialized/Open) University     8
# Name: count, dtype: int64

# %% [markdown]
# #### updating the naming convention of the type of university column

# %%
type_mapping = {
    'PA': 'Public (State) University',
    'PN': 'Public (Specialized/Open) University',
    'HP': 'Private University',
    'D': 'Deemed University'
}

karnataka_universities['Type_of_University'] = (
    karnataka_universities['Type_of_University']
    .map(type_mapping)
)

# %%
karnataka_universities
# Out:
#                                    Name_of_University  \
# 0                     Bangalore University, Bangalore
# 1                           Bengaluru City University
# 2                          Bengaluru North University
# 3                     Davangere University, Davangere
# 4                       Gulbarga University, Gulbarga
# 5                       Karnataka Sanskrit University
# 6           Karnataka State Women University, Bijapur
# 7                       Karnataka University, Dharwad
# 8         Kuvempu University, Shankaraghatta, Shimoga
# 9                     Mangalore University, Mangalore
# 10                Rani Channamma University, Belagavi
# 11                          Tumkur University, Tumkur
# 12                      University of Mysore , Mysore
# 13    Vesveswaraiah Technological University, Belgaum
# 14  Vijayanagara Sri Krishnadevaraya University, B...
# 15        University of Agricultural Science, Raichur
# 16            Karnataka State Open University, Mysore
# 17              Kannada University, Hampi, Kamalapura
# 18       Karnataka Janapada Vishwavidyalaya, Gotagodi
# 19  Karnataka State Dr. Gangubai Hangal Music And ...
# 20                        Maharani Cluster University
# 21                                  Mandya University
# 22                             Nrupathunga University
# 23  Dr .B. R. Ambedkar School of Economics University
# 24                        Adichunchanagiri University
# 25                     Alliance University. Bangalore
# 26                  Azim Premji University, Bangalore
# 27                          CMR University, Bangalore
# 28                         Dayananda Sagar University
# 29                  Garden City University, Bangalore
# 30      JSS Science And Technology University, Mysore
# 31                     K.L.E Technological University
# 32              Khaja Bandanawaz University, Gulbarga
# 33  M.S. Ramaiah University Of Applied Sciences, B...
# 34                           PES University, Banglore
# 35                  Presidency University , Bengaluru
# 36                         Reva University, Bangalore
# 37               Sharanabasava University, Kalaburagi
# 38      Shri Dharmasthala Manjunatheshwara University
# 39                     Srinivas University, Mangalore
# 40  The University Of Trans-Disciplinary Health Sc...
# 41                       B.L.D.E. University, Bijapur
# 42                       Christ University, Bangalore
# 43  International Institute Of Information Technol...
# 44             Indian Institute Of Science, Bangalore
# 45                          Jain University,Bangalore
# 46  Jawaharlal Nehru Centre For Advanced Scientifi...
# 47         Jss Academy Of Higher Education & Research
# 48  K.L.E. Academy Of Higher Education And Researc...
# 49       Manipal Academy Of Higher Education, Manipal
# 50                        Nitte University, Mangalore
# 51  Sri Devraj Urs Acaedmy Of Highehr Education An...
# 52  Sri Siddharatha Academy Of Higher Education, T...
# 53  Swami Vivekananda Yoga Anusandhana Samsthan, B...
# 54  Yenepoya ( deemed to be University), Deralakat...
#
#                       Type_of_University
# 0              Public (State) University
# 1              Public (State) University
# 2              Public (State) University
# 3              Public (State) University
# 4              Public (State) University
# 5              Public (State) University
# 6              Public (State) University
# 7              Public (State) University
# 8              Public (State) University
# 9              Public (State) University
# 10             Public (State) University
# 11             Public (State) University
# 12             Public (State) University
# 13             Public (State) University
# 14             Public (State) University
# 15             Public (State) University
# 16  Public (Specialized/Open) University
# 17  Public (Specialized/Open) University
# 18  Public (Specialized/Open) University
# 19  Public (Specialized/Open) University
# 20  Public (Specialized/Open) University
# 21  Public (Specialized/Open) University
# 22  Public (Specialized/Open) University
# 23  Public (Specialized/Open) University
# 24                    Private University
# 25                    Private University
# 26                    Private University
# 27                    Private University
# 28                    Private University
# 29                    Private University
# 30                    Private University
# 31                    Private University
# 32                    Private University
# 33                    Private University
# 34                    Private University
# 35                    Private University
# 36                    Private University
# 37                    Private University
# 38                    Private University
# 39                    Private University
# 40                    Private University
# 41                     Deemed University
# 42                     Deemed University
# 43                     Deemed University
# 44                     Deemed University
# 45                     Deemed University
# 46                     Deemed University
# 47                     Deemed University
# 48                     Deemed University
# 49                     Deemed University
# 50                     Deemed University
# 51                     Deemed University
# 52                     Deemed University
# 53                     Deemed University
# 54                     Deemed University

# %%
import matplotlib.pyplot as plt

type_counts = karnataka_universities['Type_of_University'].value_counts()

plt.figure()
type_counts.plot(
    kind='pie',
    autopct='%1.1f%%',   # shows percentages
    startangle=90        # rotates for better view
)

plt.title('Distribution of Universities in Karnataka by Type')
plt.ylabel('')  # removes default y-label
plt.tight_layout()
plt.show()
